# %%
import pandas as pd

pd.set_option('display.max_columns', None)

chunks = pd.read_json("../data/data.json", lines=True, chunksize=10000)

# %%
i = 0
chunk_list = []
for chunk in chunks:
    chunk = chunk.loc[(chunk["following_list"].notna()) & (chunk["repo_list"].notna())]
    chunk = chunk.loc[(chunk["is_suspicious"] == False) 
                    & (chunk["type"] == "User") 
                    & (chunk["bio"].notna())
                    & (chunk["company"].notna())
                    & (chunk["following_list"].map(lambda d: len(d)) > 0)
                    & (chunk["repo_list"].map(lambda d: len(d)) > 0)
                ]

    df_subset = chunk[["id", "company", "bio", "follower_list", "following_list", "repo_list"]]
    df_subset
    chunk_list.append(df_subset)

df = pd.concat(chunk_list)

df.to_csv("../data/data.csv", encoding='utf-8', index=False)
df
# Out:
#                id                                     company  \
# 1010038  20465856                                 Expanse EXP
# 1010311    152194                                      vmware
# 1010424   1755162                                     Zendesk
# 1010544  25781567                                      imfree
# 1010546   6347031                                          小米
# ...           ...                                         ...
# 1109557    523933                                  Thought.is
# 1109570  13886933                                 Avenue Code
# 1109635  11920077  Foxfire Consulting & Rapid App Development
# 1109789   1063495                                  @Microsoft
# 1109853   9121474                                        Krak
#
#                                                        bio  \
# 1010038  Founder of the Cryptocurrency Collectors Club,...
# 1010311                 make IT infrastructure more boring
# ...

# %%
df = df.loc[(df["following_list"].notna()) & (df["repo_list"].notna())]
df = df.loc[(df["is_suspicious"] == False) 
                & (df["type"] == "User") 
                & (df["bio"].notna())
                & (df["company"].notna())
                & (df["following_list"].map(lambda d: len(d)) > 0)
                & (df["repo_list"].map(lambda d: len(d)) > 0)
            ]

df_subset = df[["id", "company", "bio", "follower_list", "following_list", "repo_list"]]
df_subset
# Out:
# Empty DataFrame
# Columns: [hirable, public_repos, is_suspicious, updated_at, id, blog, followers, location, follower_list, type, commit_list, bio, commits, company, following_list, public_gists, name, created_at, email, following, login, repo_list]
# Index: []
# Empty DataFrame
# Columns: [id, company, bio, follower_list, following_list, repo_list]
# Index: []

# %%
for index, row in df.iterrows():
    languages = [d["language"] for d in row['repo_list']]
    languages = [i for i in set(languages) if i is not None]
    print(languages)
# Out:
# []
# []
# []
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jsnsw\Desktop\RecSys\notebooks\exploration.ipynb Cell 4 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jsnsw/Desktop/RecSys/notebooks/exploration.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> for index, row in df.iterrows():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jsnsw/Desktop/RecSys/notebooks/exploration.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     languages = [d["language"] for d in row['repo_list']]
#       <a href='vscode-notebook-cell:/c%3A/Users/jsnsw/Desktop/RecSys/notebooks/exploration.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     languages = [i for i in set(languages) if i is not None]
#       <a href='vscode-notebook-cell:/c%3A/Users/jsnsw/Desktop/RecSys/notebooks/exploration.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a>     print(languages)
#
# ...
